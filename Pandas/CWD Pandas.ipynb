# %%
import pandas as pd
import numpy as np
print("Libraries imported!")
# Out:
# Libraries imported!

# %%
df = pd.read_excel("Data.xlsx")

# %%
df
# Out:
#       Name  School  Marks
# 0  Shubham     SPS     34
# 1   Joshua     UPS     45
# 2     Jack     WPS     45
# 3     Alex     UIS     67
# 4  Jasmine     RTS     45
# 5    Rohan     RRY     88
# 6    Rishi  Luxury     77
# 7   Aakash     BBL     90
